# %% [markdown]
# # Understanding the convolution

# %%
# %pip install numpy scipy matplotlib watermark
# Out:
# Requirement already satisfied: numpy in ./.venv/lib/python3.14/site-packages (2.4.3)
# Requirement already satisfied: scipy in ./.venv/lib/python3.14/site-packages (1.17.1)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting watermark
#   Using cached watermark-2.6.0-py3-none-any.whl.metadata (15 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: ipython>=6.0 in ./.venv/lib/python3.14/site-packages (from watermark) (9.11.0)
# Collecting importlib-metadata>=1.4 (from watermark)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.14/site-packages (from watermark) (82.0.1)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.14/site-packages (from importlib-metadata>=1.4->watermark) (3.23.0)
# Requirement already satisfied: decorator>=5.1.0 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.14/site-packages (from ipython>=6.0->watermark) (5.14.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.14/site-packages (from jedi>=0.18.2->ipython>=6.0->watermark) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.14/site-packages (from pexpect>4.6->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.0->watermark) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.0->watermark) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.0->watermark) (0.2.3)
# Using cached matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
# Using cached watermark-2.6.0-py3-none-any.whl (13 kB)
# Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, importlib-metadata, fonttools, cycler, contourpy, matplotlib, watermark
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [watermark]/8 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 importlib-metadata-8.7.1 kiwisolver-1.5.0 matplotlib-3.10.8 pyparsing-3.3.2 watermark-2.6.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The goal here is to find one non-repeating pattern in an image. First, find the pattern, then second, compute correlation.
#
#
# Let's first initialize the notebook:

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import numpy as np
phi = (np.sqrt(5)+1)/2
fig_width = 10
figsize = (fig_width, fig_width/phi)

# %%
# %mkdir -p images

# %% [markdown]
# Let's load an image
#
# (in colab, you need to download it first)

# %%
url_image = "https://4.bp.blogspot.com/-eSgcftxjewo/Tnbr-Cwm9iI/AAAAAAAAATQ/VC7Yvss2pFQ/s1600/bichon-frise-dog10.jpg" # smaller image
url_image = "https://raw.githubusercontent.com/laurentperrinet/2026-03_UE-neurosciences-computationnelles/main/unexpected-visitor.jpg" 
import urllib.request
urllib.request.urlretrieve(url_image, 'images/unexpected-visitor.jpg')

# %%
im = plt.imread('images/unexpected-visitor.jpg')

# %% [markdown]
# TODO: show the original image and print its shape

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(im);

# %% [markdown]
# TODO: downsample the image using index slicing

# %%
XXXX your code here XXXX

fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(im_downscale, cmap=plt.gray());

# %% [markdown]
# TODO: Transform to grayscale and show

# %%
XXXX your code here XXXX

fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(im_gray, cmap=plt.gray());

# %% [markdown]
# TODO: compute a convolution on the original image / check the effect of changing the mode

# %%
from scipy import ndimage

# Define a simple edge detection kernel 
kernel = np.array([[-1, -1, -1],
                   [-1,  8, -1],
                   [-1, -1, -1]])/8.

# Perform the convolution
convolved = ndimage.convolve(XXX, XXX, mode='reflect')

# Create figure and axes
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Plot original image
axes[0].imshow(image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Plot convolved image
axes[1].imshow(convolved, cmap='gray')
axes[1].set_title('Convolved Image')
axes[1].axis('off')

# %% [markdown]
# TODO: compute a convolution on the original image with a pair of Sobel operators, one horizontal, the other vertical

# %%
XXXX your code here XXXX

# %% [markdown]
# ## in practice : finding a pattern
#
# The goal here is to find one non-repeating pattern in an image. First, find the pattern, then second, compute correlation.
#
# Let's read the image:

# %%
url_image = "https://raw.githubusercontent.com/laurentperrinet/2026-03_UE-neurosciences-computationnelles/main/99999999999998.jpg" 
urllib.request.urlretrieve(url_image, 'images/99999999999998.jpg')

# %%
im = plt.imread('images/99999999999998.jpg')
im = im.sum(axis=-1)

# %%
# TODO: show the image

# %% [markdown]
# TODO: show the original image

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(XX, cmap=plt.gray());

# %% [markdown]
# TODO: show a zoom on the original image on the top left

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(XXXX);

# %% [markdown]
# TODO: show a zoom on the original image on the top right

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(XXX);

# %% [markdown]
# TODO: remove borders

# %%
im_crop = XXX
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(im, cmap=plt.gray());

# %% [markdown]
# TODO: make the Average luminance on one axis to have an idea of the size of a line

# %%
im_x = XXX
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(im_x[:100]);

# %% [markdown]
# TODO: compute the cross-correlation of this signal and plot

# %%
xcorr = np.correlate(XXXX, YYYY , 'same')*1.
xcorr /= xcorr.max()
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(xcorr);

# %% [markdown]
# TODO: check the size of the cross-correlation and plot a zoom

# %%
N_X//2, im_x.shape, xcorr.shape, im.shape

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(xcorr[(N_X//2+1):(50+N_X//2)]);

# %% [markdown]
# TODO: find the period by finding the peak value

# %%
period_X = np.argmax( XXX ) ...

# %%
print(f'{period_X=}')

# %% [markdown]
# TODO: perform the same in the ot dimension:

# %%
im_y = im.mean(axis=0)
im_y -= im_y.mean()
XXXX

XXXX

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(im_y);

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(im_y[:40]);

# %%
xcorr = np.correlate(XXXXX YYYYYY, 'same')*1.

# %%
xcorr /= xcorr.max()
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(xcorr[(N_Y//2+3):]);

# %%
xcorr /= xcorr.max()
fig, ax = plt.subplots(figsize=(fig_width, fig_width/phi**2))
ax.plot(xcorr[(N_Y//2+3):(40+N_Y//2)]);

# %%
period_Y = np.argmax(XXXXXXXXXX )

# %%
print(f'{period_Y=}')

# %% [markdown]
# TODO: extract one sample (other random choices would *most probably* fit - do not go in the borders!)

# %%
idx, idy = XXXX, YYYY
kernel = im[idx:idx+period_X, idy:idy+period_Y]

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(kernel);

# %% [markdown]
# TODO : compute cross correlation using  https://laurentperrinet.github.io//sciblog/posts/2017-09-20-the-fastest-2d-convolution-in-the-world.html or simply using pytorch

# %%
from numpy.fft  import fft2, ifft2
xcorr = np.real(ifft2(fft2(im)*fft2(kernel, s=im.shape)))

# %% [markdown]
# TODO: Now you can spot where there is a difference (and then in the rest due to kerning...)

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width))
ax.matshow(xcorr, cmap=plt.magma());

# %% [markdown]
# ## some bookkeeping for the notebook

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,matplotlib,scipy  -r -g -b
